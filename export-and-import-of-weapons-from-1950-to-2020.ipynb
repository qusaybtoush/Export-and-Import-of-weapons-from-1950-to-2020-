# %% [markdown]
# # Introduction 😃😃😃
#
# #### Export and Import of weapons(from 1950 to 2020)
#
#
# ### About Dataset
#
# - DATA SET HAS 73 columns all named after the year and rows named after the countries from 1950 to 2020.
#
#
#
# # Data Exploration 🤝🤝🤝

# %%
#Importing the basic librarires fot analysis

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("ggplot")  #using style ggplot

# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
import datetime as dt
import plotly.graph_objects as go
import plotly.express as px

# %%
#Importing the dataset
df=pd.read_csv("../input/export-and-import-of-weaponsfrom-1950-to-2020/SIPRI ARMS TRANSFER DATA.csv")

# look the data set
df.head()
# Out:
#     Supplier  1950  1951  1952  1953  1954  1955  1956  1957  1958  ...  2012  \
# 0    Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 1    Algeria   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 2     Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 3  Argentina   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 4    Armenia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
#
#    2013  2014  2015  2016  2017  2018  2019  2020  Tranfer Type
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       Export
# 1   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN       Export
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       Export
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       Export
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       Export
#
# [5 rows x 73 columns]

# %%
# looking the shape DataSet
df.shape
# Out:
# (393, 73)

# %%
df.nunique().sort_values()
# Out:
# Tranfer Type      2
# 1950             51
# 1951             57
# 1952             58
# 1953             60
#                ...
# 1981            123
# 1983            123
# 1980            125
# 1982            128
# Supplier        262
# Length: 73, dtype: int64

# %% [markdown]
# - we have 262 country

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Checking the dtypes of all the columns

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 393 entries, 0 to 392
# Data columns (total 73 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Supplier      393 non-null    object
#  1   1950          67 non-null     float64
#  2   1951          64 non-null     float64
#  3   1952          71 non-null     float64
#  4   1953          79 non-null     float64
#  5   1954          85 non-null     float64
#  6   1955          91 non-null     float64
#  7   1956          92 non-null     float64
#  8   1957          93 non-null     float64
#  9   1958          97 non-null     float64
#  10  1959          102 non-null    float64
#  11  1960          123 non-null    float64
#  12  1961          121 non-null    float64
#  13  1962          116 non-null    float64
#  14  1963          118 non-null    float64
#  15  1964          132 non-null    float64
#  16  1965          131 non-null    float64
# ...

# %%
#checking null value 
df.isna().sum()
# Out:
# Supplier          0
# 1950            326
# 1951            329
# 1952            322
# 1953            314
#                ...
# 2017            224
# 2018            227
# 2019            217
# 2020            247
# Tranfer Type      0
# Length: 73, dtype: int64

# %%
# let see the data describe
df.describe().round(2)
# Out:
#           1950     1951     1952      1953     1954     1955     1956  \
# count    67.00    64.00    71.00     79.00    85.00    91.00    92.00
# mean    242.96   359.25   465.68    608.34   479.41   442.79   527.41
# std     645.01   815.47  1181.51   1607.92  1321.08  1102.21  1298.08
# min       0.00     0.00     0.00      0.00     1.00     0.00     0.00
# 25%       4.00    14.25    13.50      6.00     9.00    13.00    16.50
# 50%      61.00    74.50    64.00     53.00    49.00   110.00   101.50
# 75%     157.00   281.25   341.00    430.50   314.00   356.50   451.75
# max    3977.00  4041.00  6890.00  10124.00  8752.00  7105.00  8502.00
#
#           1957     1958     1959  ...     2011     2012     2013     2014  \
# count    93.00    97.00   102.00  ...   167.00   167.00   167.00   172.00
# mean    506.63   529.87   424.81  ...   359.84   335.31   325.47   314.88
# std    1264.54  1371.06  1170.47  ...  1042.18  1029.79   982.23   940.76
# ...

# %%
# how much percentage Transfer Type in the dataset

df['Tranfer Type'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',shadow=True)
# Out:
# <AxesSubplot:ylabel='Tranfer Type'>

# %%
# Creat now columes with name Total

df['Total']=df.sum(axis=1)
df.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
#     Supplier  1950  1951  1952  1953  1954  1955  1956  1957  1958  ...  2013  \
# 0    Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 1    Algeria   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 2     Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 3  Argentina   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 4    Armenia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
#
#    2014  2015  2016  2017  2018  2019  2020  Tranfer Type  Total
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN       Export     0.0
# ...

# %%
#Make new dataframe for Export & Import

df_ex=df[(df["Tranfer Type"]!="Import")] #filter about Export
df_im=df[(df["Tranfer Type"]=="Import")] #filter about Import

# %%
# The 10 highest country Export weapons

top_10=df_ex.sort_values(by="Total",ascending=False,ignore_index=True).set_index("Supplier").head(10)
top_10
# Out:
#                   1950    1951    1952     1953    1954    1955    1956  \
# Supplier
# United States   1427.0  4041.0  6890.0  10124.0  6388.0  7105.0  8502.0
# Soviet Union    3977.0  3598.0  5922.0   8618.0  8752.0  5923.0  6566.0
# Russia             NaN     NaN     NaN      NaN     NaN     NaN     NaN
# United Kingdom  2282.0  3458.0  3249.0   4662.0  4448.0  4724.0  5959.0
# France             8.0    67.0    43.0    315.0   321.0   469.0   863.0
# Germany            NaN     NaN     NaN     38.0    29.0    24.0    24.0
# China              NaN     NaN     NaN      NaN     3.0     NaN    39.0
# Italy            141.0   117.0    24.0      1.0    11.0   140.0   257.0
# Czechoslovakia    17.0    15.0    15.0      9.0    46.0   947.0  1557.0
# Netherlands      199.0    58.0    20.0      7.0    77.0   255.0     9.0
#
#                   1957    1958    1959  ...    2013    2014    2015    2016  \
# Supplier                                ...
# ...

# %%
top_10["percentage"]=top_10["Total"]/df['Total'].sum()*100
top_10["percentage"]
# Out:
# Supplier
# United States     17.822855
# Soviet Union      11.434540
# Russia             3.773046
# United Kingdom     3.623263
# France             3.240648
# Germany            2.250668
# China              1.444902
# Italy              0.857324
# Czechoslovakia     0.745417
# Netherlands        0.633232
# Name: percentage, dtype: float64

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x="Supplier",y="Total",data=top_10)
plt.xticks(rotation=90)
plt.title("The 10 highest country Export weapons ")
plt.show()

# %%
# The 10 less country Export weapons

less_10=df_ex.sort_values(by="Total",ascending=True,ignore_index=True).set_index("Supplier").head(10)
less_10
# Out:
#                      1950  1951  1952  1953  1954  1955  1956  1957  1958  \
# Supplier
# Albania               NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# United Nations**      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Slovenia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Costa Rica            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Bahamas               NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Luxembourg            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# European Union**      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Niger                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FMLN (El Salvador)*   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Gabon                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                      1959  ...  2013  2014  2015  2016  2017  2018  2019  \
# Supplier                   ...
# ...

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x="Supplier",y="Total",data=less_10)
plt.xticks(rotation=90)
plt.title("The 10 less  country Export weapons ")
plt.show()

# %%
# The 10 highest country Import weapons

top_im_10=df_im.sort_values(by="Total",ascending=False,ignore_index=True).set_index("Supplier").head(10)
top_im_10
# Out:
#                  1950    1951    1952    1953    1954    1955    1956    1957  \
# Supplier
# India           141.0   277.0   104.0   430.0   265.0   350.0   366.0   980.0
# China          2572.0  2197.0  3430.0  3144.0  3500.0  1730.0  2255.0  2126.0
# Saudi Arabia      0.0     NaN     7.0     1.0     2.0    16.0    10.0    72.0
# Egypt           163.0    57.0     0.0     1.0   142.0   725.0  1065.0   479.0
# Japan             NaN     NaN     8.0   223.0   314.0   408.0   757.0  1059.0
# Turkey          117.0   136.0   315.0   514.0   473.0   335.0   198.0   544.0
# Germany           NaN     NaN     NaN     NaN     NaN    85.0  1356.0  2270.0
# South Korea     155.0   256.0   266.0   263.0   158.0   354.0   454.0   278.0
# Iraq              NaN     NaN    59.0    53.0    19.0    61.0   105.0    38.0
# United States   352.0   695.0   875.0  1315.0  1896.0  1892.0  2071.0  1371.0
#
#                  1958    1959  ...    2013    2014    2015    2016    2017  \
# ...

# %%
top_im_10["percentage"]=top_im_10["Total"]/df['Total'].sum()*100
top_im_10["percentage"]
# Out:
# Supplier
# India            3.210778
# China            2.047909
# Saudi Arabia     1.793289
# Egypt            1.716345
# Japan            1.669373
# Turkey           1.446498
# Germany          1.424026
# South Korea      1.415918
# Iraq             1.375002
# United States    1.196539
# Name: percentage, dtype: float64

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x="Supplier",y="Total",data=top_im_10)
plt.xticks(rotation=90)
plt.title("The 10 highest country Import weapons ")
plt.show()

# %%
# The 10 less country Import weapons

less_im_10=df_im.sort_values(by="Total",ascending=True,ignore_index=True).set_index("Supplier").head(10)
less_im_10
# Out:
#                          1950  1951  1952  1953  1954  1955  1956  1957  1958  \
# Supplier
# PKK (Turkey)*             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# PIJ (Israel/Palestine)*   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# LRA (Uganda)*             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# NLA (Macedonia)*          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ANC (South Africa)*       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# RPF (Rwanda)*             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# PRC (Israel/Palestine)*   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# RUF (Sierra Leone)*       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# UIC (Somalia)*            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# MNLF (Philippines)*       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                          1959  ...  2013  2014  2015  2016  2017  2018  2019  \
# ...

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x="Supplier",y="Total",data=less_im_10)
plt.xticks(rotation=90)
plt.title("The 10 less country Import weapons ")
plt.show()

# %%
# show The 10 highest country Export weapons

top_10
# Out:
#                   1950    1951    1952     1953    1954    1955    1956  \
# Supplier
# United States   1427.0  4041.0  6890.0  10124.0  6388.0  7105.0  8502.0
# Soviet Union    3977.0  3598.0  5922.0   8618.0  8752.0  5923.0  6566.0
# Russia             NaN     NaN     NaN      NaN     NaN     NaN     NaN
# United Kingdom  2282.0  3458.0  3249.0   4662.0  4448.0  4724.0  5959.0
# France             8.0    67.0    43.0    315.0   321.0   469.0   863.0
# Germany            NaN     NaN     NaN     38.0    29.0    24.0    24.0
# China              NaN     NaN     NaN      NaN     3.0     NaN    39.0
# Italy            141.0   117.0    24.0      1.0    11.0   140.0   257.0
# Czechoslovakia    17.0    15.0    15.0      9.0    46.0   947.0  1557.0
# Netherlands      199.0    58.0    20.0      7.0    77.0   255.0     9.0
#
#                   1957    1958    1959  ...    2014    2015    2016     2017  \
# Supplier                                ...
# ...

# %%
# make transmission

top_10=top_10.T
top_10.drop(index=["Tranfer Type","Total","percentage"],inplace=True,axis=1)
top_10
# Out:
# Supplier United States Soviet Union  Russia United Kingdom  France Germany  \
# 1950            1427.0       3977.0     NaN         2282.0     8.0     NaN
# 1951            4041.0       3598.0     NaN         3458.0    67.0     NaN
# 1952            6890.0       5922.0     NaN         3249.0    43.0     NaN
# 1953           10124.0       8618.0     NaN         4662.0   315.0    38.0
# 1954            6388.0       8752.0     NaN         4448.0   321.0    29.0
# ...                ...          ...     ...            ...     ...     ...
# 2016            9868.0          NaN  6790.0         1393.0  2088.0  2506.0
# 2017           12070.0          NaN  6088.0         1237.0  2359.0  1944.0
# 2018            9895.0          NaN  6753.0          703.0  1784.0  1070.0
# 2019           10788.0          NaN  5226.0          907.0  3269.0   978.0
# 2020            9372.0          NaN  3203.0          429.0  1995.0  1232.0
#
# Supplier   China  Italy Czechoslovakia Netherlands
# ...

# %%
top_10.plot(figsize=(20,7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Results Analysis ❤️😃❤️😃❤️😃❤️😃
#
# ### Some analysis and more frequent names country showed. 🎉🎉🎉
#
# ### Export and Import of weapons(from 1950 to 2020)
#
# - We have 264 country
#
# - 66 % Import Weapons
# - 44 % Export Weapons
#
# ## Export weapons
#
# ### The 10 highest country Export weapons
#
# - United States
# - Soviet Union
# - Russia
# - United Kingdom
# - France
# - Germany
# - China
# - Italy
# - Czechoslovakia
# - Netherlands
#
#
# ### The 10 less country Export weapons
#
#
# - Albania
# - United Nations
# - Slovenia
# - Costa Rica
# - Bahamas
# - Luxembourg
# - European Union
# - Niger
# - FMLN (El Salvador)
# - Gabon
#
#
# ## Import weapons
#
# ### The 10 highest country Import weapons
#
# - India
# - China
# - Saudi Arabia
# - Egypt
# - Japan
# - Turkey
# - Germany
# - South Korea
# - Iraq
# - United States
#
#
#
# ### The 10 less country Import weapons
#
# - PKK (Turkey)
# - PIJ (Israel/Palestine)
# - LRA (Uganda)
# - NLA (Macedonia)
# - ANC (South Africa)
# - RPF (Rwanda)
# - PRC (Israel/Palestine)
# - RUF (Sierra Leone)
# - UIC (Somalia)
# - MNLF (Philippines)

# %% [markdown]
# # The End 🎉🎉🎉🎉
#
# - Thank for reading my analysis ,
# - If you any questions or advice me please write in the comment ,
#
# # Vote 🤝🤝🤝🤝🤝
#
# - also if you liked my analysis upvote me ,
